# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import shap
import os
import pickle
from matplotlib import pyplot as plt

# the following packages need to be imported into the site-packages folder
from config import properties as p
from src.utils import utils as u

# %%
"""
Run the following command if there is an import error for shap
python pip install numba --upgrade
"""

# %%
all_shap_filename = os.listdir(p.shap_path)
all_shap = [u.load_model(os.path.join(p.shap_path, f)) for f in all_shap_filename]

# %%
for i, (filename, shap_obj) in enumerate(zip(all_shap_filename, all_shap)):
    print(filename)
    shap.summary_plot(shap_obj)
    plt.show()
# Out:
# ANN_SHAP_Value.pkl
# Ensemble_Stacking_SHAP_Value.pkl
# Ensemble_Voting_SHAP_Value.pkl
# LightGBM_SHAP_Value.pkl
# LSTM_SHAP_Value.pkl
# RandomForest_SHAP_Value.pkl
# XGBoost_SHAP_Value.pkl

# %%
for i, (filename, shap_obj) in enumerate(zip(all_shap_filename, all_shap)):
    print(filename)
    shap.summary_plot(shap_obj, plot_type="bar")
    plt.show()
# Out:
# ANN_SHAP_Value.pkl
# Ensemble_Stacking_SHAP_Value.pkl
# Ensemble_Voting_SHAP_Value.pkl
# LightGBM_SHAP_Value.pkl
# LSTM_SHAP_Value.pkl
# RandomForest_SHAP_Value.pkl
# XGBoost_SHAP_Value.pkl
